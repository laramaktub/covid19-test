# %% [markdown]
# ***IMÁGENES SIN ETIQUETA***

# %%
import random
from csv import reader


original=list(range(94))

original_labels=[]
with open('Labels.csv', 'r') as read_obj:
    csv_reader = reader(read_obj)
    header = next(csv_reader)
    # Check file as empty
    i=0
    if header != None:
        for row in csv_reader:
            label="Covid19"
            if row[2]=='0':
                label="Normal"
            original_labels.append(label)
            i+=1
            

sin_etiqueta = list(zip(original,original_labels))

random.seed(30)
random_sin_etiqueta=random.sample(original,94)
contains_duplicates = len(random_sin_etiqueta) != len(set(random_sin_etiqueta))
print("Contains duplicates: ", contains_duplicates)
j=0
for idx, val in enumerate(random_sin_etiqueta):
    print("Image_"+str(idx), sin_etiqueta[val])
    j+=1
# Out:
# Contains duplicates:  False
# Image_0 (69, 'Covid19')
# Image_1 (37, 'Normal')
# Image_2 (78, 'Covid19')
# Image_3 (3, 'Normal')
# Image_4 (79, 'Covid19')
# Image_5 (83, 'Normal')
# Image_6 (26, 'Normal')
# Image_7 (32, 'Covid19')
# Image_8 (6, 'Normal')
# Image_9 (50, 'Covid19')
# Image_10 (48, 'Covid19')
# Image_11 (82, 'Covid19')
# Image_12 (17, 'Covid19')
# Image_13 (10, 'Normal')
# Image_14 (59, 'Normal')
# Image_15 (0, 'Covid19')
# Image_16 (66, 'Covid19')
# Image_17 (31, 'Covid19')
# Image_18 (90, 'Covid19')
# Image_19 (9, 'Normal')
# Image_20 (20, 'Covid19')
# Image_21 (67, 'Covid19')
# Image_22 (51, 'Normal')
# Image_23 (44, 'Covid19')
# Image_24 (68, 'Covid19')
# Image_25 (8, 'Normal')
# Image_26 (71, 'Normal')
# Image_27 (75, 'Covid19')
# Image_28 (76, 'Normal')
# Image_29 (35, 'Covid19')
# Image_30 (54, 'Normal')
# Image_31 (36, 'Normal')
# Image_32 (85, 'Normal')
# Image_33 (43, 'Normal')
# Image_34 (81, 'Covid19')
# Image_35 (40, 'Normal')
# Image_36 (64, 'Covid19')
# Image_37 (7, 'Normal')
# Image_38 (39, 'Normal')
# Image_39 (65, 'Covid19')
# Image_40 (19, 'Covid19')
# Image_41 (93, 'Normal')
# Image_42 (53, 'Normal')
# Image_43 (72, 'Covid19')
# Image_44 (16, 'Covid19')
# Image_45 (86, 'Covid19')
# Image_46 (5, 'Covid19')
# Image_47 (52, 'Normal')
# Image_48 (15, 'Covid19')
# Image_49 (70, 'Covid19')
# Image_50 (73, 'Covid19')
# Image_51 (56, 'Covid19')
# Image_52 (1, 'Covid19')
# Image_53 (87, 'Normal')
# Image_54 (88, 'Normal')
# Image_55 (84, 'Covid19')
# Image_56 (11, 'Normal')
# Image_57 (33, 'Covid19')
# Image_58 (92, 'Normal')
# Image_59 (30, 'Covid19')
# Image_60 (21, 'Normal')
# Image_61 (55, 'Covid19')
# Image_62 (28, 'Covid19')
# Image_63 (27, 'Covid19')
# Image_64 (62, 'Covid19')
# Image_65 (80, 'Normal')
# Image_66 (49, 'Normal')
# Image_67 (63, 'Normal')
# Image_68 (2, 'Normal')
# Image_69 (91, 'Normal')
# Image_70 (60, 'Normal')
# Image_71 (77, 'Covid19')
# Image_72 (45, 'Normal')
# Image_73 (29, 'Normal')
# Image_74 (46, 'Normal')
# Image_75 (23, 'Covid19')
# Image_76 (38, 'Normal')
# Image_77 (89, 'Normal')
# Image_78 (47, 'Covid19')
# Image_79 (58, 'Normal')
# Image_80 (25, 'Covid19')
# Image_81 (13, 'Normal')
# Image_82 (34, 'Normal')
# Image_83 (4, 'Covid19')
# Image_84 (61, 'Normal')
# Image_85 (22, 'Normal')
# Image_86 (57, 'Covid19')
# Image_87 (42, 'Normal')
# Image_88 (12, 'Covid19')
# Image_89 (74, 'Covid19')
# Image_90 (18, 'Normal')
# Image_91 (14, 'Normal')
# Image_92 (41, 'Normal')
# Image_93 (24, 'Covid19')

# %% [markdown]
# ***IMÁGENES CON ETIQUETA***

# %%
sin_etiqueta = list(zip(original,original_labels))

random.seed(42)
random_sin_etiqueta=random.sample(original,94)
j=0
for idx, val in enumerate(random_sin_etiqueta):
    print("Image_"+str(idx), sin_etiqueta[val])
    j+=1
# Out:
# Image_0 (81, 'Covid19')
# Image_1 (14, 'Normal')
# Image_2 (3, 'Normal')
# Image_3 (35, 'Covid19')
# Image_4 (31, 'Covid19')
# Image_5 (28, 'Covid19')
# Image_6 (17, 'Covid19')
# Image_7 (13, 'Normal')
# Image_8 (69, 'Covid19')
# Image_9 (11, 'Normal')
# Image_10 (75, 'Covid19')
# Image_11 (54, 'Normal')
# Image_12 (4, 'Covid19')
# Image_13 (91, 'Normal')
# Image_14 (84, 'Covid19')
# Image_15 (27, 'Covid19')
# Image_16 (29, 'Normal')
# Image_17 (64, 'Covid19')
# Image_18 (80, 'Normal')
# Image_19 (71, 'Normal')
# Image_20 (25, 'Covid19')
# Image_21 (85, 'Normal')
# Image_22 (53, 'Normal')
# Image_23 (88, 'Normal')
# Image_24 (57, 'Covid19')
# Image_25 (90, 'Covid19')
# Image_26 (0, 'Covid19')
# Image_27 (20, 'Covid19')
# Image_28 (82, 'Covid19')
# Image_29 (43, 'Normal')
# Image_30 (68, 'Covid19')
# Image_31 (9, 'Normal')
# Image_32 (86, 'Covid19')
# Image_33 (48, 'Covid19')
# Image_34 (21, 'Normal')
# Image_35 (6, 'Normal')
# Image_36 (5, 'Covid19')
# Image_37 (24, 'Covid19')
# Image_38 (58, 'Normal')
# Image_39 (22, 'Normal')
# Image_40 (65, 'Covid19')
# Image_41 (38, 'Normal')
# Image_42 (16, 'Covid19')
# Image_43 (2, 'Normal')
# Image_44 (46, 'Normal')
# Image_45 (77, 'Covid19')
# Image_46 (34, 'Normal')
# Image_47 (7, 'Normal')
# Image_48 (56, 'Covid19')
# Image_49 (72, 'Covid19')
# Image_50 (63, 'Normal')
# Image_51 (18, 'Normal')
# Image_52 (40, 'Normal')
# Image_53 (39, 'Normal')
# Image_54 (23, 'Covid19')
# Image_55 (36, 'Normal')
# Image_56 (12, 'Covid19')
# Image_57 (93, 'Normal')
# Image_58 (50, 'Covid19')
# Image_59 (92, 'Normal')
# Image_60 (42, 'Normal')
# Image_61 (44, 'Covid19')
# Image_62 (47, 'Covid19')
# Image_63 (78, 'Covid19')
# Image_64 (83, 'Normal')
# Image_65 (37, 'Normal')
# Image_66 (8, 'Normal')
# Image_67 (89, 'Normal')
# Image_68 (66, 'Covid19')
# Image_69 (79, 'Covid19')
# Image_70 (32, 'Covid19')
# Image_71 (45, 'Normal')
# Image_72 (74, 'Covid19')
# Image_73 (55, 'Covid19')
# Image_74 (30, 'Covid19')
# Image_75 (76, 'Normal')
# Image_76 (41, 'Normal')
# Image_77 (49, 'Normal')
# Image_78 (87, 'Normal')
# Image_79 (51, 'Normal')
# Image_80 (73, 'Covid19')
# Image_81 (52, 'Normal')
# Image_82 (10, 'Normal')
# Image_83 (19, 'Covid19')
# Image_84 (60, 'Normal')
# Image_85 (15, 'Covid19')
# Image_86 (67, 'Covid19')
# Image_87 (1, 'Covid19')
# Image_88 (26, 'Normal')
# Image_89 (33, 'Covid19')
# Image_90 (62, 'Covid19')
# Image_91 (61, 'Normal')
# Image_92 (59, 'Normal')
# Image_93 (70, 'Covid19')

# %% [markdown]
# ***HEAT MAP***

# %%
sin_etiqueta = list(zip(original,original_labels))

random.seed(57)
random_sin_etiqueta=random.sample(original,94)
j=0
for idx, val in enumerate(random_sin_etiqueta):
    print("Image_"+str(idx), sin_etiqueta[val])
    j+=1
# Out:
# Image_0 (5, 'Covid19')
# Image_1 (47, 'Covid19')
# Image_2 (75, 'Covid19')
# Image_3 (77, 'Covid19')
# Image_4 (2, 'Normal')
# Image_5 (28, 'Covid19')
# Image_6 (65, 'Covid19')
# Image_7 (41, 'Normal')
# Image_8 (61, 'Normal')
# Image_9 (37, 'Normal')
# Image_10 (55, 'Covid19')
# Image_11 (81, 'Covid19')
# Image_12 (48, 'Covid19')
# Image_13 (89, 'Normal')
# Image_14 (21, 'Normal')
# Image_15 (66, 'Covid19')
# Image_16 (90, 'Covid19')
# Image_17 (92, 'Normal')
# Image_18 (82, 'Covid19')
# Image_19 (50, 'Covid19')
# Image_20 (13, 'Normal')
# Image_21 (62, 'Covid19')
# Image_22 (69, 'Covid19')
# Image_23 (32, 'Covid19')
# Image_24 (17, 'Covid19')
# Image_25 (18, 'Normal')
# Image_26 (71, 'Normal')
# Image_27 (91, 'Normal')
# Image_28 (19, 'Covid19')
# Image_29 (54, 'Normal')
# Image_30 (22, 'Normal')
# Image_31 (84, 'Covid19')
# Image_32 (27, 'Covid19')
# Image_33 (23, 'Covid19')
# Image_34 (36, 'Normal')
# Image_35 (33, 'Covid19')
# Image_36 (70, 'Covid19')
# Image_37 (14, 'Normal')
# Image_38 (15, 'Covid19')
# Image_39 (64, 'Covid19')
# Image_40 (67, 'Covid19')
# Image_41 (25, 'Covid19')
# Image_42 (42, 'Normal')
# Image_43 (73, 'Covid19')
# Image_44 (26, 'Normal')
# Image_45 (88, 'Normal')
# Image_46 (0, 'Covid19')
# Image_47 (40, 'Normal')
# Image_48 (29, 'Normal')
# Image_49 (78, 'Covid19')
# Image_50 (1, 'Covid19')
# Image_51 (24, 'Covid19')
# Image_52 (3, 'Normal')
# Image_53 (39, 'Normal')
# Image_54 (79, 'Covid19')
# Image_55 (44, 'Covid19')
# Image_56 (58, 'Normal')
# Image_57 (80, 'Normal')
# Image_58 (45, 'Normal')
# Image_59 (43, 'Normal')
# Image_60 (87, 'Normal')
# Image_61 (76, 'Normal')
# Image_62 (72, 'Covid19')
# Image_63 (11, 'Normal')
# Image_64 (30, 'Covid19')
# Image_65 (35, 'Covid19')
# Image_66 (20, 'Covid19')
# Image_67 (31, 'Covid19')
# Image_68 (63, 'Normal')
# Image_69 (8, 'Normal')
# Image_70 (57, 'Covid19')
# Image_71 (83, 'Normal')
# Image_72 (46, 'Normal')
# Image_73 (93, 'Normal')
# Image_74 (4, 'Covid19')
# Image_75 (34, 'Normal')
# Image_76 (74, 'Covid19')
# Image_77 (51, 'Normal')
# Image_78 (85, 'Normal')
# Image_79 (60, 'Normal')
# Image_80 (49, 'Normal')
# Image_81 (38, 'Normal')
# Image_82 (6, 'Normal')
# Image_83 (86, 'Covid19')
# Image_84 (59, 'Normal')
# Image_85 (56, 'Covid19')
# Image_86 (68, 'Covid19')
# Image_87 (12, 'Covid19')
# Image_88 (16, 'Covid19')
# Image_89 (9, 'Normal')
# Image_90 (53, 'Normal')
# Image_91 (52, 'Normal')
# Image_92 (10, 'Normal')
# Image_93 (7, 'Normal')
